# %% [markdown]
# # Multi-Layer Game of Life Image Animator
#
# This notebook uses a cellular automaton (like Conway's Game of Life) to create an animation that "dissolves" an uploaded image back to a random-like state.
#
# **Instructions:**
# 1. Run the cell below.
# 2. Use the widget to upload an image.
# 3. Adjust the simulation rules, update style, and number of colors.
# 4. Click "Run & Reverse" to start the simulation.
# 5. Use the player controls to view the animation.

# %%
# %matplotlib widget
from IPython.display import display
from utilities import GOLImageApp

# Create and display the application
app = GOLImageApp(grid_size=128, steps=60)
display(app.ui)
